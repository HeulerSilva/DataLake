# %%
despachantes = spark.read.load("/Volumes/workspace/df_project1/data/despachantes.csv",
                     format="csv", sep=",", inferSchema=True, header=False)
despachantes.show()

# %%
despachantes.write.mode("overwrite").saveAsTable("workspace.df_project1.despachantes")

# %%
# %sql
SELECT * FROM workspace.df_project1.despachantes LIMIT 10;
